# %% [markdown]
# 讀取設定檔

# %%
# 引入模組
# dotenv -> .env(另一種做法)
from configparser import ConfigParser
# 讀取 config.ini 檔案取得資料庫連線資訊
config = ConfigParser()
config.read('config.ini')

# 讀取 DB 區塊
print(config['DB'])
# 讀取 host
print(config['DB']['host'])
# 讀取 user
print(config['DB']['user'])

print(config['OPENAI']['OPENAI_KEY'])
# Out:
# <Section: DB>
# localhost
# root
# adsfghjkqweryuiohjl

# %% [markdown]
# 使用設定檔建立資料庫連線

# %%
import pymysql
from configparser import ConfigParser

# 讀取 config.ini 檔案取得資料庫連線資訊
config = ConfigParser()
config.read('config.ini')
# 建立資料庫連線
connection = pymysql.connect(
    host=config['DB']['host'],
    user=config['DB']['user'],
    password=config['DB']['password'],
    port=int(config['DB']['port']), #資料型別問題 預設資料為str -> 作強制轉型
    cursorclass=pymysql.cursors.DictCursor,
)

with connection.cursor() as cursor:
    query = """
        SHOW DATABASES;
    """
    cursor.execute(query)
    result = cursor.fetchall()
print(result)
# Out:
# [{'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_database'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'transaction_test'}, {'Database': 'world'}]

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# 使用 SQL 函式

# %%
#要再看一次
# %reload_ext autoreload
from sql_utils import sql_query, show_dbs

dbs = show_dbs()
print(dbs)
data = sql_query("SHOW TABLES FROM my_titanic;")
print(data)
# Out:
# [{'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_database'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'transaction_test'}, {'Database': 'world'}]
# [{'Tables_in_my_titanic': 'full_passengers'}]

# %%
# %reload_ext autoreload
from sql_utils import SqlUtils

db = SqlUtils()
dbs = db.show_dbs()
print(dbs)
dbs2 = db.sql_query(db.db_query)#用類別屬性帶入查詢語句
print(dbs2)
tables = db.sql_query('SHOW TABLES FROM my_titanic;')
print(tables)
# Out:
# [{'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_database'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'transaction_test'}, {'Database': 'world'}]
# [{'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_database'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'transaction_test'}, {'Database': 'world'}]
# [{'Tables_in_my_titanic': 'full_passengers'}]

# %%
# %reload_ext autoreload
from sql_utils import SqlUtils

titanic_db = SqlUtils('my_titanic')

tables = titanic_db.sql_query('SHOW TABLES;')
print(tables)
result = titanic_db.sql_query('SELECT * FROM full_passengers;')
print(result[0])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[28], line 6
#       2 from sql_utils import SqlUtils
#       3
#       4 titanic_db = SqlUtils('my_titanic')
#       5
# ----> 6 tables = titanic_db.sql_query('SHOW TABLES;')
#       7 print(tables)
#       8 result = titanic_db.sql_query('SELECT * FROM full_passengers;')
#       9 print(result[0])
#
# File <string>:8, in SqlUtils.sql_query(self, query)
#       6 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\cursors.py:159, in Cursor.execute(self, query, args)
#     155     pass
#     157 query = self.mogrify(query, args)
# --> 159 result = self._query(query)
#     160 self._executed = query
#     161 return result
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\cursors.py:330, in Cursor._query(self, q)
#     328 conn = self._get_db()
#     329 self._clear_result()
# --> 330 conn.query(q)
#     331 self._do_get_result()
#     332 return self.rowcount
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\connections.py:582, in Connection.query(self, sql, unbuffered)
#     580     sql = sql.encode(self.encoding, "surrogateescape")
#     581 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 582 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     583 return self._affected_rows
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\connections.py:847, in Connection._read_query_result(self, unbuffered)
#     845     result.init_unbuffered_query()
#     846 else:
# --> 847     result.read()
#     848 self._result = result
#     849 if result.server_status is not None:
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\connections.py:1245, in MySQLResult.read(self)
#    1243 def read(self):
#    1244     try:
# -> 1245         first_packet = self.connection._read_packet()
#    1247         if first_packet.is_ok_packet():
#    1248             self._read_ok_packet(first_packet)
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\connections.py:803, in Connection._read_packet(self, packet_type)
#     801     if self._result is not None and self._result.unbuffered_active is True:
#     802         self._result.unbuffered_active = False
# --> 803     packet.raise_for_error()
#     804 return packet
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\iSpan\pymysql_d3\.venv\Lib\site-packages\pymysql\err.py:154, in raise_mysql_exception(data)
#     152 if errorclass is None:
#     153     errorclass = InternalError if errno < 1000 else OperationalError
# --> 154 raise errorclass(errno, errval, sqlstate=sqlstate)
#
# OperationalError: (1046, 'No database selected')
