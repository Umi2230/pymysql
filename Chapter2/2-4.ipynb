# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext autoreload
from sql_utils import create_database, create_user_table

create_database('chapter2')
create_user_table('chapter2')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [{'Database': 'chapter2'}, {'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_database'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'testdb'}, {'Database': 'transaction_test'}, {'Database': 'world'}]
# [{'Tables_in_chapter2': 'user'}]

# %%
# %load_ext autoreload
from sql_utils import create_user

create_user('Jane', 27, 'Jane654', '654321')
# Out:
# [{'id': 9, 'name': 'Jane', 'age': 27, 'username': 'Jane654', 'password': '654321'}]

# %%
#補充 若參數值相同 可使用* **
#**可使用在dict的合併
def add(*args, **kwargs):
    print(args)
    print(kwargs)

add(1, 2, 3, 4, 5, name='Um', age=25)
# Out:
# (1, 2, 3, 4, 5)
# {'name': 'Um', 'age': 25}

# %%
#補充 實務上會使用到
user = {'name': 'Jarvis', 'age': 20}

# 在不知道 **dict 的用法時 可能會這樣寫
info = {'role': 'admin', 'name': user['name'], 'age': user['age']}

# **dict 做賦值
info = {"role": "admin", **user, 'age': 30}

print(info)
# Out:
# {'role': 'admin', 'name': 'Jarvis', 'age': 30}
